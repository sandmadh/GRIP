# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from pandas.plotting import autocorrelation_plot
import datetime
from statsmodels.tsa.arima_model import ARIMA
import statsmodels.api as sm
from textblob import TextBlob
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
from sklearn.model_selection import train_test_split
from nltk import tokenize
from sklearn.metrics import accuracy_score
from sklearn.metrics import r2_score

# %%
filename2 = 'india-news-headlines.csv'
news_df  = pd.read_csv(filename2,parse_dates=[0])

# %%
news_df.head()
# Out:
#   publish_date headline_category  \
# 0   2001-01-01        sports.wwe
# 1   2001-01-02           unknown
# 2   2001-01-02           unknown
# 3   2001-01-02           unknown
# 4   2001-01-02           unknown
#
#                                        headline_text
# 0  win over cena satisfying but defeating underta...
# 1  Status quo will not be disturbed at Ayodhya; s...
# 2                Fissures in Hurriyat over Pak visit
# 3              America's unwanted heading for India?
# 4                 For bigwigs; it is destination Goa

# %%
news_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3297172 entries, 0 to 3297171
# Data columns (total 3 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   publish_date       datetime64[ns]
#  1   headline_category  object
#  2   headline_text      object
# dtypes: datetime64[ns](1), object(2)
# memory usage: 75.5+ MB

# %%
news_df.isnull().sum()
# Out:
# publish_date         0
# headline_category    0
# headline_text        0
# dtype: int64

# %%
print("min date is ", news_df.publish_date.min())
print("max date is ", news_df.publish_date.max())
# Out:
# min date is  2001-01-01 00:00:00
# max date is  2020-06-30 00:00:00

# %%
filename1 ='^BSESN.csv'

stock_df = pd.read_csv (filename1,parse_dates=[0])

# %%
stock_df.isnull().sum()
stock_df.dropna(inplace=True)

# %%
stock_df.head()
# Out:
#         Date          Open          High           Low         Close  \
# 0 2019-10-03  38137.871094  38310.929688  37957.558594  38106.871094
# 1 2019-10-04  38401.488281  38403.539063  37633.359375  37673.308594
# 2 2019-10-07  37853.800781  37919.468750  37480.531250  37531.980469
# 3 2019-10-09  37628.050781  38209.839844  37415.828125  38177.949219
# 4 2019-10-10  38130.230469  38130.230469  37802.929688  37880.398438
#
#       Adj Close   Volume
# 0  38106.871094  59200.0
# 1  37673.308594  52900.0
# 2  37531.980469  40400.0
# 3  38177.949219  36400.0
# 4  37880.398438  27300.0

# %%
min_stock_date = stock_df.Date.min()
max_stock_date = stock_df.Date.max()
print("min date is ", stock_df.Date.min())
print("max date is ", stock_df.Date.max())
# Out:
# min date is  2019-10-03 00:00:00
# max date is  2020-10-01 00:00:00

# %%
news_stock_df = news_df[(news_df['publish_date'] >= min_stock_date) & (news_df['publish_date'] <= max_stock_date)]

# %%
 news_df_combined = news_stock_df.groupby('publish_date')['headline_text'].apply(' '.join).reset_index()

# %%
news_df_combined['Date'] = news_df_combined['publish_date']
news_df_combined.drop(columns=['publish_date'],inplace=True)
news_df_combined.head()
# Out:
#                                        headline_text       Date
# 0  meet greet bond and seize the day networking s... 2019-10-03
# 1  I am in love with a relative Why no child welf... 2019-10-04
# 2  Channapatna artisans go tech-savvy to beat dro... 2019-10-05
# 3  Getting enough prebiotics? What is Wardrobing?... 2019-10-06
# 4  Wanna smell fresh all day? Apply perfume on th... 2019-10-07

# %%
the fit couples of bollywood who workout together Mysuru Dasara in 1888: Ploughing contests and Rs 5 prizes Waste Body is a track many youngsters can relate to: Arjun Lewis Waste Body is a track many youngsters can relate to: Arjun Lewis Bengaluru comes together to remember the Mahatma Bengaluru comes together to remember the Mahatma On Panchami; I'm coming home Maa: Chirodini Ami Je Tomar actress Sharly Modak Waste dumping polluting Ranipur Rau river in Haridwar Dehradun gets its first Swachhta Kendra 60-year-old woman dies in Rishikesh; dengue suspected Uttarakhand releases 24 prisoners on Gandhi Jayanti Agra district jail release 18 prisoners on Gandhi Jayanti AMU steers clear of controversy on Gandhi's 150th birth anniversary Five get life terms for 2015 murder of gram panchayat candidate Mathura police seizes 16;000 cough syrup bottles of Rs 20 lakh Agra: Smart City works delayed due to unreleased funds Wanted cattle smuggler; three others held in police encounter in Mathura Manikonda residents waiting for drinking water since years No BJP candidates for 5 zila panchayat seats; district unit in a spot of bother Uttarakhand government should provide us work; say MSMEs owners Rebuild Jannat-ul-Baqi: Muslims to Saudi govt Research quality hit due to lack of faculty UP's TikTok villain eludes cops; drone; RAF deployed Hyderabad: Drunk woman picks up axe; severely wounds aged dog Illegal sand mining in Rampur: NGT slaps Rs 9.16 crore fine on leaseholder After Azam Khan appears before SIT with wife and son; cops claim he is being uncooperative Bareilly: SRMS trust gives scholarships to over 400 students; investing Rs 3 crore Created party after much thought; says Shivpal on any merger with SP Don't worship Gandhi; follow him: Nitish Kumar Bareilly: 18-year ...

# %%
# create the function to get subjectivity
def getSubjectivity(text):
    return TextBlob(text).sentiment.subjectivity

def getPolarity(text):
    return TextBlob(text).sentiment.polarity

def getSIA(text):
    sia = SentimentIntensityAnalyzer()
    sentiment = sia.polarity_scores(text)
    return sentiment

# %%
news_stock_df['subjectivity'] = news_stock_df['headline_text'].apply(getSubjectivity)
news_stock_df['polarity'] = news_stock_df['headline_text'].apply(getPolarity)

# %%
news_stock_df
# Out:
#                                          headline_text       Date  \
# 0    meet greet bond and seize the day networking s... 2019-10-03
# 1    I am in love with a relative Why no child welf... 2019-10-04
# 2    Wanna smell fresh all day? Apply perfume on th... 2019-10-07
# 3    Assam: Hydel project pipeline bursts; 4 washed... 2019-10-09
# 4    Ahmedabad: Dog set loose on cops; PASA- booked... 2019-10-10
# ..                                                 ...        ...
# 175  I never thought I had a voice until today: Vid... 2020-06-24
# 176  Truck firms look for new export markets to sel... 2020-06-25
# 177  Containment zone residents slam high prices ch... 2020-06-26
# 178  6 hot and stylish bikini looks of Katrina Kaif... 2020-06-29
# 179  Detective Byomkesh Bakshy! Edge of Tomorrow Fi... 2020-06-30
#
#              Open          High           Low         Close     Adj Close  \
# 0    38137.871094  38310.929688  37957.558594  38106.871094  38106.871094
# 1    38401.488281  38403.539063  37633.359375  37673.308594  37673.308594
# 2    37853.800781  37919.468750  37480.531250  37531.980469  37531.980469
# 3    37628.050781  38209.839844  37415.828125  38177.949219  38177.949219
# 4    38130.230469  38130.230469  37802.929688  37880.398438  37880.398438
# ..            ...           ...           ...           ...           ...
# 175  35679.738281  35706.550781  34794.929688  34868.980469  34868.980469
# 176  34525.390625  35081.609375  34499.781250  34842.101563  34842.101563
# 177  35144.781250  35254.878906  34910.339844  35171.269531  35171.269531
# 178  34926.949219  35032.359375  34662.058594  34961.519531  34961.519531
# 179  35168.300781  35233.910156  34812.800781  34915.800781  34915.800781
#
#       Volume  subjectivity  polarity
# 0    59200.0      0.429271  0.035780
# 1    52900.0      0.418134  0.090559
# 2    40400.0      0.427959  0.080569
# 3    36400.0      0.429184  0.080979
# 4    27300.0      0.404573  0.027153
# ..       ...           ...       ...
# 175  26600.0      0.387802  0.088329
# 176  24600.0      0.403998  0.027038
# 177  24800.0      0.381841  0.068333
# 178  18300.0      0.396828  0.061956
# 179  18500.0      0.384191  0.071554
#
# [180 rows x 10 columns]

# %%
compound = []
neg = []
pos = []
neutral = []
SIA = 0

for i in range(0, len(news_stock_df['headline_text'])):
    
    SIA = getSIA(news_stock_df['headline_text'][i])
    compound.append(SIA['compound'])
    neg.append(SIA['neg'])
    pos.append(SIA['pos'])
    neutral.append(SIA['neu'])

# %%
news_stock_df['neg'] = neg

# %%
news_stock_df['pos'] = pos

# %%
news_stock_df['neutral'] = neutral

# %%
news_stock_df['compound'] = compound

# %%
news_stock_df.head()
# Out:
#                                        headline_text       Date          Open  \
# 0  meet greet bond and seize the day networking s... 2019-10-03  38137.871094
# 1  I am in love with a relative Why no child welf... 2019-10-04  38401.488281
# 2  Wanna smell fresh all day? Apply perfume on th... 2019-10-07  37853.800781
# 3  Assam: Hydel project pipeline bursts; 4 washed... 2019-10-09  37628.050781
# 4  Ahmedabad: Dog set loose on cops; PASA- booked... 2019-10-10  38130.230469
#
#            High           Low         Close     Adj Close   Volume  \
# 0  38310.929688  37957.558594  38106.871094  38106.871094  59200.0
# 1  38403.539063  37633.359375  37673.308594  37673.308594  52900.0
# 2  37919.468750  37480.531250  37531.980469  37531.980469  40400.0
# 3  38209.839844  37415.828125  38177.949219  38177.949219  36400.0
# 4  38130.230469  37802.929688  37880.398438  37880.398438  27300.0
#
#    subjectivity  polarity    neg    pos  neutral  compound
# 0      0.429271  0.035780  0.134  0.095    0.771   -0.9998
# 1      0.418134  0.090559  0.151  0.094    0.755   -0.9999
# 2      0.427959  0.080569  0.126  0.084    0.790   -0.9998
# 3      0.429184  0.080979  0.156  0.096    0.747   -0.9999
# 4      0.404573  0.027153  0.148  0.096    0.755   -0.9999

# %%
keep_columns = ['Open','High','Low','Close','Volume','subjectivity','polarity','neg','pos','neutral','compound']

# %%
df = news_stock_df[keep_columns]

# %%
df.isnull().sum()
# Out:
# Open            0
# High            0
# Low             0
# Close           0
# Volume          0
# subjectivity    0
# polarity        0
# neg             0
# pos             0
# neutral         0
# compound        0
# dtype: int64

# %%
df.shape
# Out:
# (180, 11)

# %%
x = df.drop(columns=['Close'])
y = df['Close']
print(len(x),len(y),x.shape, y.shape)
# Out:
# 180 180 (180, 10) (180,)

# %%
xtrain,xtest,ytrain,ytest= train_test_split(x,y,test_size=0.3, random_state=42)

# %%
print(len(xtrain), len(ytrain), len(xtest), len(ytest))
# Out:
# 126 126 54 54

# %%
#implement linear regression
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
ypred = model.predict(xtest)

# %%
len(ypred)
# Out:
# 54

# %%
len(ytest)
# Out:
# 54

# %%
#comparisions between predicted and actual values

test_result = pd.DataFrame({'Actual': ytest, 'Predicted': ypred})

# %%
test_result
# Out:
#            Actual     Predicted
# 19   40301.960938  40358.312490
# 42   40445.148438  40565.802967
# 153  30672.589844  30672.116776
# 78   41198.660156  41334.994964
# 145  31371.119141  31011.503948
# 15   39831.839844  40063.398066
# 24   40345.078125  40271.937763
# 68   41872.730469  41741.875152
# 113  29915.960938  29997.704056
# 118  29815.589844  29931.389197
# 93   41323.000000  41294.894681
# 159  33825.531250  33651.357754
# 69   41932.558594  41951.896724
# 142  31443.380859  31257.553831
# 45   40412.570313  40199.725810
# 16   40051.871094  39983.530923
# 51   41673.921875  41616.392796
# 125  31159.619141  30905.118212
# 96   40281.199219  40294.069846
# 56   41575.140625  41569.441379
# 97   39888.960938  39916.386622
# 120  29468.490234  29069.891688
# 143  31642.699219  31502.149689
# 30   40651.640625  40664.437471
# 9    39052.058594  39042.205662
# 172  34731.730469  34627.680702
# 60   41464.609375  41370.113026
# 18   40165.031250  40136.644387
# 148  31097.730469  30700.136055
# 173  34911.320313  35034.143054
# 109  31390.070313  31494.379786
# 55   41163.761719  41136.949254
# 140  31453.509766  31522.902515
# 126  30690.019531  30488.717063
# 66   41859.691406  41848.708043
# 29   40469.699219  40378.368909
# 117  29946.769531  29610.458304
# 65   41599.718750  41655.916995
# 67   41952.628906  41793.714499
# 31   40575.171875  40527.324761
# 12   39058.828125  39037.221611
# 41   40779.589844  40846.880257
# 124  29893.960938  31142.503671
# 100  38144.019531  38240.218715
# 161  33980.699219  33913.433266
# 132  31379.550781  31139.364363
# 90   41257.738281  41463.014908
# 38   40802.171875  40718.239668
# 169  33605.218750  33248.570387
# 115  26674.029297  26109.280188
# 171  34208.050781  34317.116948
# 156  32200.589844  32041.086378
# 2    37531.980469  37559.276445
# 176  34842.101563  34946.115117

# %%
train_score  = model.score(xtrain,ytrain)
test_score = model.score(xtest, ytest)


print("accuracy score on train data set : ", round(train_score*100 , 2))
print("accuracy score on test data set : ", round(test_score* 100, 2))
# Out:
# accuracy score on train data set :  99.87
# accuracy score on test data set :  99.73
